# %% [markdown]
# 读写文件是最常见的IO操作。Python内置了读写文件的函数，用法和C是兼容的。
# 在磁盘上读写文件的功能都是由操作系统提供的，现代操作系统不允许普通的程序直接操作磁盘，所以，读写文件就是请求操作系统打开一个文件对象，然后，通过操作系统提供的接口从这个文件对象中读取数据（读文件），或者把数据写入这个文件对象（写文件）。

# %% [markdown]
# 读文件
#
# 要以读文件的模式打开一个文件对象，使用Python内置的open()函数，传入文件名和标示符：

# %%
f = open('test.txt', 'r') #标示符'r'表示读，这样，我们就成功地打开了一个文件

# %% [markdown]
# 如果文件不存在，open()函数就会抛出一个IOError的错误，并且给出错误码和详细的信息告诉你文件不存在
# 如果文件打开成功，接下来，调用read()方法可以一次读取文件的全部内容，Python把内容读到内存，用一个str对象表示：

# %%
f.read()
# Out:
# '123\nabc'

# %% [markdown]
# 最后一步是调用close()方法关闭文件。文件使用完毕后必须关闭，因为文件对象会占用操作系统的资源，并且操作系统同一时间能打开的文件数量也是有限的：

# %%
f.close()

# %% [markdown]
# 由于文件读写时都有可能产生IOError，一旦出错，后面的f.close()就不会调用。所以，为了保证无论是否出错都能正确地关闭文件，我们可以使用try ... finally来实现：

# %%
try:
    f = open('error.txt', 'r')
    print f.read()
finally:
    if f:
        f.close()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-5-b2d2ff431ae7> in <module>()
#       1 try:
# ----> 2     f = open('/path/to/file', 'r')
#       3     print f.read()
#       4 finally:
#       5     if f:
#
# IOError: [Errno 2] No such file or directory: '/path/to/file'

# %% [markdown]
# 但是每次都这么写实在太繁琐，所以，Python引入了with语句来自动帮我们调用close()方法：

# %%
with open('error', 'r') as f:
    print f.read()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-6-ecdcf99f291f> in <module>()
# ----> 1 with open('/path/to/file', 'r') as f:
#       2     print f.read()
#
# IOError: [Errno 2] No such file or directory: '/path/to/file'

# %% [markdown]
# 调用read()会一次性读取文件的全部内容，如果文件有10G，内存就爆了，所以，要保险起见，可以反复调用read(size)方法，每次最多读取size个字节的内容。另外，调用readline()可以每次读取一行内容，调用readlines()一次读取所有内容并按行返回list。因此，要根据需要决定怎么调用。

# %% [markdown]
# 如果文件很小，read()一次性读取最方便；如果不能确定文件大小，反复调用read(size)比较保险；如果是配置文件，调用readlines()最方便：

# %%
f = open('test.txt', 'r')
for line in f.readlines():
    print(line.strip()) # 把末尾的'\n'删掉
# Out:
# 123
# abc

# %% [markdown]
# 二进制文件
#
# 前面读取的是文本文件，并且是ASCII编码的文本文件。要读取二进制文件，比如图片、视频等等，用'rb'模式打开文件即可：

# %%
f = open('test.jpg', 'rb')
f.read()
# Out:
# '\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00H\x00H\x00\x00\xff\xe1\x00XExif\x00\x00MM\x00*\x00\x00\x00\x08\x00\x02\x01\x12\x00\x03\x00\x00\x00\x01\x00\x01\x00\x00\x87i\x00\x04\x00\x00\x00\x01\x00\x00\x00&\x00\x00\x00\x00\x00\x03\xa0\x01\x00\x03\x00\x00\x00\x01\x00\x01\x00\x00\xa0\x02\x00\x04\x00\x00\x00\x01\x00\x00\x01\xdb\xa0\x03\x00\x04\x00\x00\x00\x01\x00\x00\x01\x0c\x00\x00\x00\x00\xff\xed\x008Photoshop 3.0\x008BIM\x04\x04\x00\x00\x00\x00\x00\x008BIM\x04%\x00\x00\x00\x00\x00\x10\xd4\x1d\x8c\xd9\x8f\x00\xb2\x04\xe9\x80\t\x98\xec\xf8B~\xff\xc0\x00\x11\x08\x01\x0c\x01\xdb\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\t\n\x0b\xff\xc4\x00\xb5\x11\x00\x02\x01\x02\x04\x04\x03\x04\x07\x05\x04\x04\x00\x01\x02w\x00\x01\x02\x03\x11\x04\x05!1\x06\x12AQ\x07aq\x13"2\x81\x08\x14B\x91\xa1\xb1\xc1\t#3R\xf0\x15br\xd1\n\x16$4\xe1%\xf1\x17\x18\x19\x1a&\'()*56789:CDEFGHIJSTUVWXYZcdefghijstuvwxyzC\x00\x02\x02\x02\x02\x02\x02\x03\x02\x02\x03\x04\x03\x03\x03\x04\x05\x04\x04\x04\x04\x05\x07\x05\x05\x05\x05\x05\x07\x08\x07\x07\x07\x07\x07\x07\x08\x08\x08\x08\x08\x08\x08\x08\n\n\n\n\n\n\x0b\x0b\x0b\x0b\x0b\r\r\r\r\r\r\r\r\r\r\xff\xdb\x00C\x01\x02\x02\x02\x03\x03\x03\x06\x03\x03\x06\r\t\x07\t\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\xff\xdd\x00\x04\x00\x1e\xff\xda\x00\x0c\x03\x01\x00\x02\x11\x03\x11\x00?\x00\xfc\xd5\xf8\xb5%\xcc\x1f\x13\xbcLC8G\xd5n\x88\x198?9\xce?\x1f^\xb5\xe7\xc2\xf2\xe3\x072\xbf\xd01\xfck\xd5\xbe-\xc6\xad\xf1\x13\xc4\xe0\x8c\xb7\xf6\xb5\xdf=8\xdd\xd3\xdb\x02\xbc]\xcf\x97)E (\xfb\xa3\xd2\xb9p\xcf\xdc\x8f\xa1\xad_\x8a\xe6\x90\xbb\x9bi\x02G\xe7\xd5\x88\xa8\x9e\xee\xe1\x8e\x04\x8e\t\xeb\xc9\xaaFU\xcf\x04\xe7\xd7\xe9N\x0c:\x83\xcfpk\xa1\x92\x9d\x89\xday\xf8\xcc\x8f\xdc}\xe3Q}\xae\xe1F\xe1+\x80G\xf7\x8f\xf8\xd5y_h\xeaw\x1a\x8d[\x80\x18\x8c\xf7\xf7\xa6\x97q7\xa9|]\xce\x7f\xe5\xab\xff\x00\xdfG\x8a\xaa\xf73\xb1\xff\x00Z\xf8\xecw\x1f\xf1\xa8\x9eD^\t\x18\x07\xd7\x9a\x88?!\x81\x18\xcf>\xb8\xa6+\xe8Y/s\xb7w\x98\xfc\xff\x00\xb4\x7fJ\x89\xda\xef 4\x8e\x0f_\xbcA\x03\xe8+\xf4w\xfe\t\xed\xf0\xcf\xe1\xcf\xc4\xef\x15x\xafG\xf8\x8f\xe1\xad?\xc4\xb6\xb6\x9aTwv\xb1\xdf+7\x91)\x98!x\xca\xb2\x95b\xa7\x1dM~\x86k?\xb2\x1f\xecb\xfa\x8b\xe9\x97\xbe\x0e\xb6\xb2\xbc\x88*L\x9a}\xe5\xeaH\x8f"\xee@\xdbK\xa0b\xbc\x81\x9e\x95\xea\xff\x00eO\x92\x12\xbe\xb2\\\xda.\x97k\xf49\xd6"<\xd2\x8fgo\xc1?\xd4\xfet\x1aK\x9c\x87\xf3$\xc7\xbb\x1f\xcb\xafZ\xac\xf3]\xabn29\x07\x9c\xee=\x0f\xe3\xc5\x7fA\xef\xff\x00\x04\xf6\xfd\x93\xb5\xe9e\x87K\xb5\xd7\xad\xa4\x80\x85\x99m\xb5W\x93\xca\xdc\xa1\xc6\xe4\x9a3\x82T\x83\x8e\xb5\xc8\xea\x7f\xf0K_\x81\xb7\xc5\x13F\xf1g\x8a4\xdc\xb7F\x8a\xd2\xeb9\xf4%P\xfe\xb5\x9c\xf2\xe9\xae\xab\xf1\xff\x00"\x95h\x9f\x83\xcdqp\x18~\xf5\xd7\x9e\x9b\x8d$\xb2\\\xed/\xe6Hq\xc1\xf9\x8e+\xf6\xb7P\xff\x00\x82Gh\xcc\x8c\xfa\x07\xc4\xdb\x8c\x90H7\xba8\xdb\xc1\xee\xd1K\xd4w W\x9d\xeb\x9f\xf0I\x8f\x88\x10F\xc3A\xf8\x87\xe1\xfb\xc7\x08J\x8b\x8 ...

# %% [markdown]
# 字符编码
#
# 要读取非ASCII编码的文本文件，就必须以二进制模式打开，再解码。比如GBK编码的文件：

# %%
f = open('gbk.txt', 'rb')
u = f.read().decode('gbk')
u
#print u
# Out:
# u'\u6d4b\u8bd5'

# %% [markdown]
# 写文件
#
# 写文件和读文件是一样的，唯一区别是调用open()函数时，传入标识符'w'或者'wb'表示写文本文件或写二进制文件：

# %%
f = open('test2.txt', 'w')
f.write('Hello, world!')
f.close()

# %%
f = open('test2.txt', 'r')
f.read()
# Out:
# 'Hello, world!'

# %% [markdown]
# 你可以反复调用write()来写入文件，但是务必要调用f.close()来关闭文件。当我们写文件时，操作系统往往不会立刻把数据写入磁盘，而是放到内存缓存起来，空闲的时候再慢慢写入。只有调用close()方法时，操作系统才保证把没有写入的数据全部写入磁盘。忘记调用close()的后果是数据可能只写了一部分到磁盘，剩下的丢失了。所以，还是用with语句保险：

# %%
with open('test3.txt', 'w') as f:
    f.write('Hello, Python!')

# %% [markdown]
# 文件目录操作

# %%
import os
os.getcwd() #该函数的返回值是当前的绝对路径
# Out:
# '/Users/mymac'

# %%
#listdir(path_str)函数的返回值是一个列表，列表中包含路径path_str（字符串变量）下所有文件和目录的名称。
os.listdir(path_str)
# Out:
# ['.anaconda',
#  '.android',
#  '.bash_history',
#  '.bash_profile',
#  '.bash_profile-anaconda.bak',
#  '.bash_sessions',
#  '.CFUserTextEncoding',
#  '.conda',
#  '.condarc',
#  '.config',
#  '.cups',
#  '.DS_Store',
#  '.gitconfig',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  '.oracle_jre_usage',
#  '.pylint.d',
#  '.sogouinput',
#  '.spyder',
#  '.spyder2',
#  '.ssh',
#  '.subversion',
#  '.Trash',
#  '.vscode',
#  '.wns',
#  '.yunpan',
#  '360\xe4\xba\x91\xe7\x9b\x98',
#  'anaconda',
#  'AnacondaProjects',
#  'Applications',
#  'Applications (Parallels)',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'gbk.txt',
#  'Library',
#  'Movies',
#  'Music',
#  'Pictures',
#  'Public',
#  'PycharmProjects',
#  'Python_3.ipynb',
#  'Python_5.ipynb',
#  'Python_Share.slides.html',
#  'Python_Share1.slides.html',
#  'Python_Share2.slides.html',
#  'Python_Share3.slides.html',
#  'test.ipynb',
#  'test.jpg',
#  'test.slides.html',
#  'test.txt',
#  'test2.txt',
#  'test3.txt',
#  'Untitled.ipynb',
#  'untitled0.py',
#  'Untitled1.ipynb',
#  'untitled1.txt',
#  'Untitled2.ipynb',
#  'Untitled3.ipynb',
#  'Untitled4.ipynb',
#  'Untitled5.ipynb',
#  'Untitled6.ipynb',
#  '\xe7\x99\xbe\xe5\xba\xa6\xe4\xba\x91\xe5\x90\x8c\xe6\xad\xa5\xe7\x9b\x98']

# %%
#remove()函数用来删除"file_name"字符串所指定的文件，但是如果file_name所指定文件名称不存在就会引起错误。
os.remove("file_name")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-23-967389af953d> in <module>()
#       1 #remove()函数用来删除"file_name"字符串所指定的文件，但是如果file_name所指定文件名称不存在就会引起错误。
# ----> 2 os.remove("file_name")
#
# OSError: [Errno 2] No such file or directory: 'file_name'

# %%
try:
    os.remove("file_name")
except OSError,e:
    print('error...but continue')
print('whatever...')
# Out:
# error...but continue
# whatever...

# %% [markdown]
# Python和很多高级语言一样，内置了一套try...except...finally...的错误处理机制

# %% [markdown]
# 当我们认为某些代码可能会出错时，就可以用try来运行这段代码，如果执行出错，则后续代码不会继续执行，而是直接跳转至错误处理代码，即except语句块，执行完except后，如果有finally语句块，则执行finally语句块，至此，执行完毕。
# 下面的代码在计算10 / 0时会产生一个除法运算错误：

# %%
try:
    print 'try...'
    r = 10 / 0
    print 'result:', r
except ZeroDivisionError, e:
    print 'except:', e
finally:
    print 'finally...'
print 'END'
# Out:
# try...
# except: integer division or modulo by zero
# finally...
# END

# %% [markdown]
# 从输出可以看到，当错误发生时，后续语句print 'result:', r不会被执行，except由于捕获到ZeroDivisionError，因此被执行。最后，finally语句被执行。然后，程序继续按照流程往下走。
#
# 如果把除数0改成2，则：

# %%
try:
    print 'try...'
    r = 10 / 2
    print 'result:', r
except ZeroDivisionError, e:
    print 'except:', e
finally:
    print 'finally...'
print 'END'
# Out:
# try...
# result: 5
# finally...
# END

# %% [markdown]
# 由于没有错误发生，所以except语句块不会被执行，但是finally如果有，则一定会被执行（可以没有finally语句）。
